# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("reading_data/adult.csv",sep = ",")

# %%
df.head()        #veriyi görüntüledik.
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.shape   #satır sütun bilgisini alldık.
# Out:
# (48842, 15)

# %%
df.tail()   #sondan verileri aldık.
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
df.columns      #sütun adlarını aldık.
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df.info()       #veri tipi ve bellek bilgisini almış olduk.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.describe().T       
#veri setinin istatistiksel bilgilerini aldık.Transpozunu da alarak daha iyi bir görüntü sağladık.
# Out:
#                    count           mean            std      min       25%  \
# age              48842.0      38.643585      13.710510     17.0      28.0
# fnlwgt           48842.0  189664.134597  105604.025423  12285.0  117550.5
# educational-num  48842.0      10.078089       2.570973      1.0       9.0
# capital-gain     48842.0    1079.067626    7452.019058      0.0       0.0
# capital-loss     48842.0      87.502314     403.004552      0.0       0.0
# hours-per-week   48842.0      40.422382      12.391444      1.0      40.0
#
#                       50%       75%        max
# age                  37.0      48.0       90.0
# fnlwgt           178144.5  237642.0  1490400.0
# educational-num      10.0      12.0       16.0
# capital-gain          0.0       0.0    99999.0
# capital-loss          0.0       0.0     4356.0
# hours-per-week       40.0      45.0       99.0

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
type(df.workclass)    #veri tipini gördük.
# Out:
# pandas.core.series.Series

# %%
df = df.replace("?",np.NAN)    #soru işareti olan değerleri nan yaptık.

# %%
df.isnull().sum()   #veri setimizdeki nan değerlere baktık.
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df.isnull().sum()/len(df)    #boş hücrelerin veri setindeki  ağrılıklarına  baktık.
#Bazılarında boşluk yok bazılarında ise sadece %5 lik ,%1 lik kısmı oluşturduğunu gördük.
# Out:
# age                0.000000
# workclass          0.057307
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         0.057512
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     0.017546
# income             0.000000
# dtype: float64

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
dff = df.dropna()   #nan değerleri sildik.
#Kalıcı hale getirmek için data.dropna(how="any",inplace=True) şeklinde yazmamız gerekiyor.

# %%
dff.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
dff.dropna(subset = ["education"])      # sadece education alanındaki nan değerleri silecektir.
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
dff.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df["yeni_sutun"] = df.age    #yeni sütun ekleme

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
# ...

# %%
df.insert(2,column = "yeni_sutun3",value=df.age)  #2 indeksli yere sütun ekledik.

# %%
df.head()
# Out:
#    age  workclass  yeni_sutun3  yeni_sutun2  fnlwgt     education  \
# 0   25    Private           25           25  226802          11th
# 1   38    Private           38           38   89814       HS-grad
# 2   28  Local-gov           28           28  336951    Assoc-acdm
# 3   44    Private           44           44  160323  Some-college
# 4   18        NaN           18           18  103497  Some-college
#
#    educational-num      marital-status         occupation relationship   race  \
# 0                7       Never-married  Machine-op-inspct    Own-child  Black
# 1                9  Married-civ-spouse    Farming-fishing      Husband  White
# 2               12  Married-civ-spouse    Protective-serv      Husband  White
# 3               10  Married-civ-spouse  Machine-op-inspct      Husband  Black
# 4               10       Never-married                NaN    Own-child  White
#
#    gender  capital-gain  capital-loss  hours-per-week native-country income  \
# ...

# %%
m = df["workclass"].isin(["Private"])
#ilk olarak sütunu belirttim.
#isin parametresiylede istediğim değeri yazdım.

# %%
df[m]        #workclass ı sadece private olanları getirdim.filtrelem işlemi yaptık.
# Out:
#        age workclass  yeni_sutun3  yeni_sutun2  fnlwgt     education  \
# 0       25   Private           25           25  226802          11th
# 1       38   Private           38           38   89814       HS-grad
# 3       44   Private           44           44  160323  Some-college
# 5       34   Private           34           34  198693          10th
# 8       24   Private           24           24  369667  Some-college
# ...    ...       ...          ...          ...     ...           ...
# 48836   22   Private           22           22  310152  Some-college
# 48837   27   Private           27           27  257302    Assoc-acdm
# 48838   40   Private           40           40  154374       HS-grad
# 48839   58   Private           58           58  151910       HS-grad
# 48840   22   Private           22           22  201490       HS-grad
#
#        educational-num      marital-status         occupation   relationship  \
# ...

# %%
yas_aralik = df["age"].between(20,40)  #aralık filtreleme

# %%
df[yas_aralik]      #20 ile 40 yaş arasını filtrelemiş oldum.
# Out:
#        age  workclass  yeni_sutun3  yeni_sutun2  fnlwgt     education  \
# 0       25    Private           25           25  226802          11th
# 1       38    Private           38           38   89814       HS-grad
# 2       28  Local-gov           28           28  336951    Assoc-acdm
# 5       34    Private           34           34  198693          10th
# 8       24    Private           24           24  369667  Some-college
# ...    ...        ...          ...          ...     ...           ...
# 48834   32    Private           32           32  116138       Masters
# 48836   22    Private           22           22  310152  Some-college
# 48837   27    Private           27           27  257302    Assoc-acdm
# 48838   40    Private           40           40  154374       HS-grad
# 48840   22    Private           22           22  201490       HS-grad
#
#        educational-num      marital-status         occupation   relationship  \
# ...

# %%
df["education"].unique()  #eşsiz değerleri verir.
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
df["education"].nunique() #kaç adet eşsiz değer olduğunu verir.
# Out:
# 16

# %%
df.rename({"yeni_sutun3":"sutun3","yeni_sutun2":"sutu"},axis="columns",inplace = True)
